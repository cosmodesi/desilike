# %% [markdown]
# # ShapeFit Tests
#
# This notebook tests the `refactor-jax` version of shapefit against the main version's as the examples of either seem to give different results

# %%
import os
import re
import shutil

# Path to your feature branch (the one you renamed to desilikemain)
BASE_DIR = "/global/homes/d/dforero/codes/desilike-main/desilike/desilikemain"

# Walk through all Python files and replace 'desilike' as a module name
for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        if file.endswith('.py'):
            filepath = os.path.join(root, file)
            with open(filepath, 'r') as f:
                content = f.read()
            # Replace whole-word 'desilike' with 'desilikemain'
            # This catches: import desilike, from desilike import ..., from desilike.submodule import ...
            new_content = re.sub(r'\bdesilike\b', 'desilikemain', content)
            if new_content != content:
                with open(filepath, 'w') as f:
                    f.write(new_content)
                print(f"Updated: {filepath}")

# Remove all __pycache__ folders to avoid stale bytecode
for root, dirs, files in os.walk(BASE_DIR):
    if '__pycache__' in dirs:
        shutil.rmtree(os.path.join(root, '__pycache__'))
        print(f"Removed: {os.path.join(root, '__pycache__')}")

print("All imports updated to 'desilikemain'.")
# Out:
# All imports updated to 'desilikemain'.

# %%
import sys
sys.path.insert(0, "/global/homes/d/dforero/codes/desilike-main/desilike")
import desilikemain
import desilike


print(desilikemain.__file__)
print(desilike.__file__)
# Out:
# /global/homes/d/dforero/codes/desilike-main/desilike/desilikemain/parameter.py:1011: SyntaxWarning: invalid escape sequence '\_'
#   latex_namespace = namespace if provided_namespace else (r'\mathrm{%s}' % namespace.replace('\_', '_').replace('_', '\_'))
# /global/homes/d/dforero/codes/desilike-main/desilike/desilikemain/parameter.py:1011: SyntaxWarning: invalid escape sequence '\_'
#   latex_namespace = namespace if provided_namespace else (r'\mathrm{%s}' % namespace.replace('\_', '_').replace('_', '\_'))
# /global/homes/d/dforero/codes/desilike-main/desilike/desilikemain/__init__.py
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20260321-1.0.0/code/desilike/refactor-jax/lib/python3.12/site-packages/desilike/__init__.py

# %% [markdown]
# ## Fake power spectrum data

# %%
import numpy as np
from matplotlib import pyplot as plt

from cosmoprimo.fiducial import DESI

cosmo = DESI()
edges = np.linspace(0., 0.3, 31)
edges = np.column_stack([edges[:-1], edges[1:]])
k = np.mean(edges, axis=-1)
nmodes = 4. * np.pi / 3. * (edges[..., 1]**3 - edges[..., 0]**3)
z = 1.
pk = cosmo.get_fourier().pk_interpolator(of='delta_cb')(k, z=z)
b = 2.
f = cosmo.growth_rate(z)
shotnoise = np.ones_like(k) / 5e-4
volume = 1e10

ells = (0, 2, 4)
poles = []
poles.append((b**2 + 2. / 3. * f * b + 1. / 5. * f**2) * pk + shotnoise)
poles.append((4. / 3. * f * b + 4. / 7. * f**2) * pk)
poles.append(8. / 35 * f**2 * pk)
poles = np.array(poles, dtype='f8')

from lsstypes import Mesh2SpectrumPole, Mesh2SpectrumPoles
mean = [Mesh2SpectrumPole(k=k, k_edges=edges, num_raw=value, num_shotnoise=(ell == 0) * shotnoise, ell=ell) for ell, value in zip(ells, poles)]
mean = Mesh2SpectrumPoles(mean)

cov = [2. * (2. * np.pi)**3 / (2 * ell + 1) / (volume * nmodes) * poles[0]**2 for ell in ells]
cov = np.diag(np.concatenate(cov, axis=0))

rng = np.random.RandomState(seed=42)
mocks = []
for i in range(1001):
    tmp = mean.clone(value=rng.multivariate_normal(mean.value().ravel(), cov))
    mocks.append(tmp)
data, mocks = mocks[0], mocks[1:]

# %% [markdown]
# ## JAX ShapeFit likelihood

# %%
from desilike.theories.galaxy_clustering import ShapeFitSpectrum2Template, KaiserTracerSpectrum2Poles
from desilike.observables.galaxy_clustering import Spectrum2PolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike import setup_logging, compile, get_params
import lsstypes


template = ShapeFitSpectrum2Template(z=z, fiducial='DESI')
theory = KaiserTracerSpectrum2Poles(template=template)

data_sel = data.get(ells=[0, 2]).select(k=(0.02, 0.2))  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
covariance = lsstypes.cov(mocks).at.observable.match(data_sel)
observable = Spectrum2PolesObservable(data=data_sel, covariance=covariance, theory=theory)

# NOTE: parameter customization must happen AFTER building the observable above, not before:
# Spectrum2PolesObservable.__init__ calls theory.update(k=..., ells=...) internally to align the
# theory's grid with the data, which (being a full re-__init__) would otherwise silently
# discard any customization made on theory's params beforehand.
params = get_params(observable)
params['b1'].update(value=2.)  # start from the truth
# Narrow reference distributions (used to draw starting points for profilers / samplers)
params['dm'].update(ref={'limits': [-0.001, 0.001]})
params['df'].update(ref={'limits': [0.99, 1.01]})
for name in ['qpar', 'qper']: params[name].update(ref={'limits': [0.998, 1.002]})

likelihood = ObservablesGaussianLikelihood(observables=[observable])

# NOTE: if we wanted to fit xi instead:
# theory = KaiserTracerCorrelation2Poles(template=template)
# observable = Correlation2PolesObservable(data=data_sel, covariance=covariance,
#                                          theory=theory)  # with data_sel = data.get(ells=[0, 2]).select(s=(40., 160.))
# The rest would be the same

setup_logging()
pipe = compile(likelihood)
print('logL at default parameters =', pipe())
# Out:
# logL at default parameters = -17.96845823056523

# %%
from desilike import TaylorEmulator

# Taylor-expand the theory as set up by the observable (k and ells aligned with the data),
# around the current parameter values: order 2 in all parameters, except sn0
# (the theory is linear in sn0, so order 1 is enough)
theory_graph = compile(theory)
order = {name: 2 for name in get_params(theory).select(varied=True, derived=False).names()}
order['sn0'] = 1
emulator = TaylorEmulator(theory_graph, order=order)
emulator.fit()

# NOTE: the pre-refactor Emulator.check()/.plot() convenience methods no longer exist;
# compare the emulator directly against the original model instead
point = dict(qpar=1.002, qper=0.998, dm=0.005, df=1.005, b1=2.1, sn0=0.1)
y_true = np.asarray(theory_graph(**point))
y_emu, _ = emulator.predict(point)
print('Max relative emulation error:', np.max(np.abs(np.asarray(y_emu) / y_true - 1.)))

import os
base_dir = '_tests'
os.makedirs(base_dir, exist_ok=True)
kaiser_emulator_fn = os.path.join(base_dir, 'kaiser_emulator.h5')
emulator.write(kaiser_emulator_fn)
# Out:
# [000004.98]  09-03 00:53  TaylorEmulator               INFO     Varied parameters: ['df', 'dm', 'qpar', 'qper', 'b1', 'sn0']
# Max relative emulation error: 3.8183863705243404e-05

# %% [markdown]
# ## Sampling
# Let us draw MC samples of the likelihood (actually posterior, including parameter priors).

# %%
from desilike import Sampler, Posterior
from desilike.samplers import Zeus

# Swap the theory for its emulator: update() re-runs the observable's __init__ in-place with
# the new theory (the likelihood holds the same observable instance, so it picks up the swap
# when we recompile below). The emulated calculator is a drop-in replacement for the original.
emulated = TaylorEmulator.read(kaiser_emulator_fn).to_calculator()
#observable.update(theory=emulated)

# Sample the posterior = likelihood + priors: wrap the likelihood in Posterior.
# (Sampling the bare likelihood would let walkers wander far outside the priors,
# where the Taylor emulator extrapolates arbitrarily badly.)
pipe = compile(Posterior(likelihood))

sampler = Sampler(pipe, kernel=Zeus(), rng=42, output_dir='_tests/chain_fs_shapefit_jax')
# We run samples until convergence, considered reached when Gelman-Rubin stabilizes below 1.05
samples = sampler.run(min_steps=500, gelman_rubin=1.01)
# Out:
# [000027.75]  09-03 00:53  EnsembleSampler              INFO     Varied parameters: ['df', 'dm', 'qpar', 'qper', 'b1', 'sn0']
# [000027.75]  09-03 00:53  EnsembleSampler              INFO     Samples will be written to: _tests/chain_fs_shapefit_jax
# [000027.84]  09-03 00:53  root                         INFO     Initialising ensemble of 24 walkers...
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20260321-1.0.0/code/desilike/refactor-jax/lib/python3.12/site-packages/desilike/samplers/zeus.py:61: UserWarning: Zeus does not support random seeds. Results are not deterministic.
#   warnings.warn('Zeus does not support random seeds. Results are not deterministic.')
# [000038.46]  09-03 00:54  EnsembleSampler              INFO     Diagnostics:
# [000038.64]  09-03 00:54  EnsembleSampler              INFO     Gelman-Rubin: 1
# [000038.64]  09-03 00:54  EnsembleSampler              INFO     1 < 1.01 (passed)
# ...

# %%
# Evaluate the likelihood at the maximum-posterior sample and plot the fit
names = get_params(likelihood).select(varied=True, derived=False).names()
idx = np.unravel_index(np.argmax(samples.logposterior), samples.logposterior.shape)
best = {name: np.asarray(samples[name].value)[idx] for name in names}
pipe(**best)
observable.plot()
plt.show()

# %%
chain = samples.remove_burnin(0.5)[::10]
print(chain.to_stats(tablefmt='pretty'))
# Out:
# +------+---------+---------+---------+--------+-----------------+-----------------+
# |      | argmax  |  mean   | median  |  std   | quantile:1sigma | interval:1sigma |
# +------+---------+---------+---------+--------+-----------------+-----------------+
# |  df  |  0.994  |  0.991  |  0.991  | 0.010  | +0.0102/-0.0099 | +0.0098/-0.0101 |
# |  dm  | -0.0020 | -0.0011 | -0.0011 | 0.0061 | +0.0059/-0.0057 | +0.0059/-0.0057 |
# | qpar | 1.0007  | 1.0003  | 1.0003  | 0.0025 | +0.0026/-0.0025 | +0.0021/-0.0029 |
# | qper | 0.9955  | 0.9942  | 0.9942  | 0.0049 | +0.0049/-0.0050 | +0.0049/-0.0047 |
# |  b1  | 1.9919  | 1.9897  | 1.9899  | 0.0090 | +0.0091/-0.0090 | +0.0084/-0.0094 |
# | sn0  | 0.0023  | 0.0023  | 0.0024  | 0.0030 | +0.0030/-0.0030 | +0.0024/-0.0034 |
# +------+---------+---------+---------+--------+-----------------+-----------------+

# %%
from desilike.samples import plotting
plotting.plot_triangle(chain, markers={'qpar': 1., 'qper': 1., 'df': 1., 'dm': 0., 'b1': b, 'sn0': 0.})
# Out:
# Removed no burn in
# [000042.49]  09-03 00:54  matplotlib.mathtext          INFO     Substituting symbol \perp from STIXGeneral
# [000042.50]  09-03 00:54  matplotlib.mathtext          INFO     Substituting symbol \perp from STIXGeneral
# [000044.29]  09-03 00:54  matplotlib.mathtext          INFO     Substituting symbol \perp from STIXGeneral
# [000044.30]  09-03 00:54  matplotlib.mathtext          INFO     Substituting symbol \perp from STIXGeneral

# %% [markdown]
# ## Main version of the test

# %%
# ------------------------------------------------------------
# Test the 'desilikemain' feature branch
# All imports and objects are explicitly from desilikemain
# ------------------------------------------------------------

from desilikemain.theories.galaxy_clustering import ShapeFitPowerSpectrumTemplate, KaiserTracerPowerSpectrumMultipoles
from desilikemain.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilikemain.likelihoods import ObservablesGaussianLikelihood
from desilikemain.parameter import Parameter, ParameterPrior
from desilikemain import setup_logging as setup_logging_main

# Set up logging for the feature version
setup_logging_main()

# Create the template using desilikemain classes
template_main = ShapeFitPowerSpectrumTemplate(z=z, fiducial='DESI')
template_main.params['dm'].update(ref={'limits': [-0.001, 0.001]}, delta=0.001)
template_main.params['df'].update(ref={'limits': [0.99, 1.01]}, delta=0.001)
for name in ['qpar', 'qper']:
    template_main.params[name].update(ref={'limits': [0.998, 1.002]}, delta=0.001)

# Build the theory object
theory_main = KaiserTracerPowerSpectrumMultipoles(template=template_main)
theory_main.params['b1'].update(value=2.)

# Build the observable
observable_main = TracerPowerSpectrumMultipolesObservable(
    data=data,
    covariance=mocks,
    klim={0: [0.02, 0.2], 2: [0.02, 0.2]},  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
    theory=theory_main
)

# Build the likelihood
likelihood_main = ObservablesGaussianLikelihood(observables=[observable_main])

# Initialize and compute
likelihood_main()  # calls the likelihood with current parameters

import jax
with jax.checking_leaks():
    likelihood_main()
# Out:
# [000000.49] [0/1] 09-03 01:03  ObservablesGaussianLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000000.49] [0/1] 09-03 01:03  ObservablesGaussianLikelihood INFO     ...resulting in a Hartlap 2007 factor of 0.9630.
# [000003.65] [0/1] 09-03 01:03  ObservablesGaussianLikelihood INFO     Covariance matrix with 36 points built from 1000 observations, varying 6 parameters.
# [000003.65] [0/1] 09-03 01:03  ObservablesGaussianLikelihood INFO     ...resulting in a Percival 2014 factor of 1.0238.

# %%
# ------------------------------------------------------------
# Test desilikemain: Emulator + Sampler
# All imports and objects are explicitly from desilikemain
# ------------------------------------------------------------

import os
import matplotlib.pyplot as plt
jax.config.update('jax_disable_jit', True)   # disable JIT

from desilikemain.samplers import NautilusSampler
from desilikemain.samples import plotting


# --- Run the sampler using the desilikemain likelihood ---
sampler_main = NautilusSampler(
    likelihood_main,
    directory='_tests/chain_sf_main_chains',
    seed=42
)
sampler_main.run(check={'max_eigen_gr': 0.1})

# --- Evaluate the likelihood at the best-fit point ---
likelihood_main(**sampler_main.chains[0].choice(index='argmax', input=True))
observable_main.plot()
plt.show()

# --- Analyse the chain ---
chain_main = sampler_main.chains[0].remove_burnin(0.5)
print(chain_main.to_stats(tablefmt='pretty'))

# --- Triangle plot ---
# Markers show the true values (adjust b1 to the value you set earlier, e.g., 2.0)
plotting.plot_triangle(
    chain_main,
    markers={
        'qpar': 1.0,
        'qper': 1.0,
        'df': 1.0,
        'dm': 0.0,
        'b1': 2.0,      # match the value set in theory_main.params['b1']
        'sn0': 0.0
    }
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTracerError                     Traceback (most recent call last)
# Cell In[22], line 15
#      11 from desilikemain.samples import plotting
#      14 # --- Run the sampler using the desilikemain likelihood ---
# ---> 15 sampler_main = NautilusSampler(
#      16     likelihood_main,
#      17     directory='_tests/chain_sf_main_chains',
#      18     seed=42
#      19 )
#      20 sampler_main.run(check={'max_eigen_gr': 0.1})
#      22 # --- Evaluate the likelihood at the best-fit point ---
#
# File ~/codes/desilike-main/desilike/desilikemain/samplers/nautilus.py:41, in NautilusSampler.__init__(self, likelihood, rng, directory, **kwargs)
#      37 if not NAUTILUS_INSTALLED:
#      38     raise ImportError("The 'nautilus-sampler' package is required but "
#      39                       "not installed.")
# ---> 41 super().__init__(likelihood, rng=rng, directory=directory)
# ...

# %% [markdown]
# # Modified shapefit for bispec

# %% [markdown]
# ## Fake bispectrum data

# %%
import numpy as np
import jax
from matplotlib import pyplot as plt

from cosmoprimo.fiducial import DESI

from geofptax.kernels import bk_sugiyama_multip, weights_trapz, pt_kernel, pt_pk_1loop
from lsstypes.base import CovarianceMatrix

cosmo = DESI()
dk_bin = 0.005
edges = np.arange(0.02, 0.12, dk_bin)
edges = np.column_stack([edges[:-1], edges[1:]])
k_ev = np.mean(edges, axis=1)

nmodes = 4. * np.pi / 3. * (edges[..., 1]**3 - edges[..., 0]**3)
z = 1.
kt = jnp.linspace(0.01, 1., 1000)
q = kt
pk = cosmo.get_fourier().pk_interpolator(of='delta_cb')(kt, z=z)
b = 2.
f = cosmo.growth_rate(z)
shotnoise = np.ones_like(k) / 5e-4
volume = 1e10
wq = weights_trapz(q)
kernel = pt_kernel(kt, q, wq)
pkt = sum(pt_pk_1loop(kt, q, wq, pk, kernel))

cosm_par = np.array([1.,f, 1., 1., b, 0., 0., 4., 0., 5.])

# [ $\sigma_8$ , $f$, $\alpha_\parallel$, $\alpha_\bot$, $b_1$ , $b_2$ , $A_P$, $\sigma_P$, $A_B$, $\sigma_B$]
bk_sugi = jax.jit(bk_sugiyama_multip, static_argnames = ("num_points",))(k_ev, k_ev, kt, pkt, cosm_par,redshift=z, num_points = 50)
print(bk_sugi.keys())

ells = ['000', '202']
from lsstypes import Mesh3SpectrumPole, Mesh3SpectrumPoles
mean_b = [Mesh3SpectrumPole(k=k_ev, k_edges=edges, num_raw=bk_sugi[ell], ell=tuple(map(int, tuple(ell))),  basis = 'sugiyama') for ell in ells]
mean_b = Mesh3SpectrumPoles(mean_b,)
print(mean_b)


from functools import partial
from geofptax.kernels import jax_leggauss, compute_basis_grid 
@partial(jax.jit, static_argnames=('num_points',))
def compute_sugiyama_variance(k1k2_pairs, log_km, log_pkm, V, dk,
                               num_points=50, n_bar=None,
                               symmetry_factor=1.0):
    """
    Compute the Gaussian (disconnected) variance of the 6 Sugiyama 
    tripolar spherical harmonic multipoles.

    Uses the exact same basis functions, H-factor normalizations, and 
    Gauss-Legendre quadrature grid as `compute_sugiyama_multipoles`.

    In the Gaussian limit the covariance is diagonal in multipole space, so
    only the variance (diagonal) is returned.

    Parameters
    ----------
    k1k2_pairs : jnp.ndarray
        Array of shape (N_pairs, 2) with columns (k1, k2).
        For the 1-D projection set k1 = k2 for every row.
    log_km : jnp.ndarray
        log10 of wavevector magnitudes for power-spectrum interpolation.
    log_pkm : jnp.ndarray
        log10 of power-spectrum values for interpolation.
    V : float
        Effective survey volume  (Mpc/h)^3.
    dk : float
        Width of the k-bin (h/Mpc).  Used to count Fourier modes.
    num_points : int
        Number of Gauss-Legendre points per angular axis (default 50).
    n_bar : float or None
        Mean galaxy number density  (h/Mpc)^3.
        If given, shot noise 1/n_bar is added to every P(k) inside the
        Gaussian variance (P → P + 1/n_bar).
    symmetry_factor : float
        Extra symmetry factor: use 2.0 when k1 = k2 (isosceles triangles),
        6.0 for equilateral, 1.0 otherwise.

    Returns
    -------
    variances : jnp.ndarray
        Shape (6, N_pairs).  Variance of each of the 6 normalised Sugiyama
        coefficients [000, 110, 220, 202, 022, 112] for every (k1, k2) pair.
        The 1-sigma error bar is simply  jnp.sqrt(variances).

    Notes
    -----
    Gaussian variance formula used:

        Var[B_i(k1,k2)] = s_B * (2π)^3
                          -------------------------
                          V * dk^2 * k1^2 * k2^2

                          × ∫ dx dμ dφ  |W_i(x,μ,φ)|^2
                                        × P_tot(k1) P_tot(k2) P_tot(k3(x))

    where P_tot = P + 1/n_bar  (or just P if n_bar is None),
    k3(x) = sqrt(k1^2 + k2^2 + 2 k1 k2 x),
    s_B = symmetry_factor, and W_i are the H-factor-normalised Sugiyama
    basis functions from `compute_basis_grid`.

    This is the *disconnected* (Gaussian) piece only.  It is accurate on
    large scales; on quasi-linear / nonlinear scales the connected
    (trispectrum) piece adds extra variance.
    """
    

    # ── 1.  Quadrature grid (identical to compute_sugiyama_multipoles) ───
    x_pts, x_wts = jax_leggauss(jnp.arange(num_points))
    mu_pts, mu_wts = jax_leggauss(jnp.arange(num_points))
    phi_pts, phi_wts = jax_leggauss(jnp.arange(num_points))

    phi_wts = phi_wts * jnp.pi          # rescale to [0, 2π]

    X, M, P = jnp.meshgrid(x_pts, mu_pts, phi_pts, indexing='ij')
    Wx, Wm, Wp = jnp.meshgrid(x_wts, mu_wts, phi_wts, indexing='ij')
    W_total = Wx * Wm * Wp              # shape (Nx, Nmu, Nphi)

    # ── 2.  Basis functions (your existing routine) ──────────────────────
    basis_grid = compute_basis_grid(x_pts, mu_pts, phi_pts)   # (6, Nx, Nmu, Nphi)

    # H-factors (same as in compute_sugiyama_multipoles)
    H_factors = jnp.array([
        1.0,
        -1.0 / jnp.sqrt(3.0),
         1.0 / jnp.sqrt(5.0),
         1.0 / jnp.sqrt(5.0),
         1.0 / jnp.sqrt(5.0),
         jnp.sqrt(2.0 / 15.0),
    ])

    # Pre-compute |H_i * W_i|^2 on the grid  →  shape (6, Nx, Nmu, Nphi)
    HW_sq = (H_factors[:, None, None, None] * basis_grid) ** 2

    # ── 3.  Power-spectrum helper ────────────────────────────────────────
    sn = 0.0 if n_bar is None else 1.0 / n_bar

    def P_tot(logk):
        return 10.0 ** jnp.interp(logk, log_km, log_pkm) + sn

    # ── 4.  Per-pair variance computation ────────────────────────────────
    def _variance_pair(k1k2):
        k1, k2 = k1k2[0], k1k2[1]

        # P(k1) and P(k2) are constant over the angular grid
        pk1 = P_tot(jnp.log10(k1))
        pk2 = P_tot(jnp.log10(k2))

        # k3 depends on x12 only  →  shape (Nx, 1, 1) for broadcasting
        k3 = jnp.sqrt(k1**2 + k2**2 + 2.0 * k1 * k2 * X)   # (Nx, Nmu, Nphi)
        pk3 = P_tot(jnp.log10(jnp.maximum(k3, 1e-10)))      # guard log(0)

        # Gaussian disconnected integrand at every grid point
        gauss_integrand = pk1 * pk2 * pk3                    # scalar × scalar × (Nx,Nmu,Nphi)

        # Integrate  |H_i W_i|^2  ×  P(k1) P(k2) P(k3)  over angles
        raw_var = jnp.sum(HW_sq * gauss_integrand[None, ...] * W_total[None, ...],
                          axis=(1, 2, 3))                     # shape (6,)

        # ── 5.  Survey prefactor ─────────────────────────────────────────
        # Number of modes in each shell:  N(k) = V * 4π k^2 dk / (2π)^3
        # Variance prefactor = (2π)^3 / (V dk^2 k1^2 k2^2)
        # The 4π * 2π from the solid-angle integrals is already absorbed
        # into the quadrature weights.
        prefactor = symmetry_factor * (2.0 * jnp.pi) ** 3 / (V * dk**2 * k1**2 * k2**2)

        return prefactor * raw_var

    # Vectorise over all (k1, k2) pairs
    variances = jax.vmap(_variance_pair)(k1k2_pairs)          # (N_pairs, 6)

    return variances.T                                        # (6, N_pairs)

k1k2_pairs = jnp.column_stack([k_ev, k_ev])       # (30, 2)
variances = compute_sugiyama_variance(
    k1k2_pairs, jnp.log(kt), jnp.log(pk),
    V=volume, dk=dk_bin,
    num_points=50,
    n_bar=5e-4,
    symmetry_factor=2.0,       # isosceles (k1 = k2)
)
labels = ['000', '110', '220', '202', '022', '112']
sigma = dict(zip(labels, jnp.sqrt(variances)))    # shape (6, 30)

cov_b = jnp.diag(jnp.concatenate([sigma['000'], sigma['202']], axis = -1))
cov_b = CovarianceMatrix(cov_b, observable = mean_b)
cov = CovarianceMatrix(cov, observable = mean)


rng = np.random.RandomState(seed=42)
mocks_b = []
mocks_joint = []
for i in range(1001):
    tmp = mean_b.clone(value=rng.multivariate_normal(mean_b.value().ravel(), cov_b))
    mocks_b.append(tmp)
    _mean = mean.get(ells=[0, 2]).select(k=(0.02, 0.2))
    _cov = cov.at.observable.match(_mean).value()
    tmp = rng.multivariate_normal(np.concatenate([_mean.value().ravel(), 
                                                  mean_b.value().ravel()], axis = -1), 
                                  np.diag(np.concatenate(list(map(np.diag, [_cov, cov_b])))))
    mocks_joint.append(tmp)
data_b, mocks_b = mocks_b[0], mocks_b[1:]

print(np.array(mocks_joint).shape)
# Out:
# sizes (Array(1000, dtype=int64),) (Array(1000, dtype=int64),) (Array(1000, dtype=int64),)
# dict_keys(['000', '022', '110', '112', '202', '220'])
# Mesh3SpectrumPoles(labels=[{'ells': (0, 0, 0)}, {'ells': (2, 0, 2)}], size=38)
# /tmp/ipykernel_922950/3666042799.py:196: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   tmp = mean_b.clone(value=rng.multivariate_normal(mean_b.value().ravel(), cov_b))
# (1001, 74)
# (74, 74)

# %%
cov_joint = np.cov(np.array(mocks_joint).T)
print(cov_joint.shape)
plt.errorbar(k_ev, k_ev**2 * bk_sugi['000'], yerr = k_ev**2 * jnp.sqrt(sigma['000']))
plt.figure()
std = np.sqrt(np.diag(cov_joint))
plt.imshow(cov_joint / (std[:,None] * std[None,:]))
# Out:
# (74, 74)

# %%
from desilike.theories.galaxy_clustering.template import (BAOTheory, Spectrum2Template, 
                                                            propose_params_multitracer, 
                                                            _ap_auto_params, assign_params,
                                                            _get_fiducial, _kw_pk, _ap_k_mu)
from desilike.base import Parameter
import jax.numpy as jnp
#from desilike.theories.galaxy_clustering._multitracer import assign_params

class ShapeFitApTheory(BAOTheory):
    r"""Extract ShapeFit parameters from a cosmology provider, on top of the BAO distance ratios.

    Following https://arxiv.org/abs/2106.07641 (eq. 3.11), at each call, on top of the
    :class:`BAOTheory` observables, computes from the registered cosmology:

    .. math::

        m = \left.\frac{d \ln P^{\rm now}(k)}{d \ln k}\right|_{k = k_p s}, \quad
        A_p = \frac{1}{s^3} P^{\rm now}(k_p s), \quad
        s = \frac{r_d}{r_{d,\rm fid}}

    where :math:`P^{\rm now}` is the no-wiggle linear power spectrum (divided by the
    primordial power spectrum times :math:`k` when ``n_varied``, which changes the
    definition of :math:`m`), and the ratios to the fiducial:

    .. math::

        dm = m - m_{\rm fid}, \quad dn = n_s - n_{s,\rm fid}, \quad
        df = \frac{f \sqrt{A_p}}{(f \sqrt{A_p})_{\rm fid}}

    with :math:`f = \sigma_{8,\theta_{cb}} / \sigma_{8,\delta_{cb}}` the growth rate.

    Parameters
    ----------
    z : float, default=1.
        Effective redshift.
    eta : float, default=1./3.
        Exponent defining the DV combination.
    kp : float, default=0.03
        Pivot wavenumber [h/Mpc] of the ShapeFit parameterization.
    n_varied : bool, default=False
        Use the second-order ShapeFit parameter ``n``; this changes the definition of ``m``.
    with_now : str, default='peakaverage'
        Engine for the no-wiggle power spectrum.
    fiducial : str or cosmoprimo.Cosmology, default='DESI'
        Fiducial cosmology used to normalise the ratios.
    cosmo : PrimordialCosmology, optional
        Cosmology provider; a :class:`CosmoprimoCosmology` is created if not given.

    Attributes
    ----------
    m, n, f_sqrt_Ap : JAX scalar
        ShapeFit slope, primordial index and power-spectrum amplitude parameters.
    dm, dn, df : JAX scalar
        Ratios / differences relative to the fiducial cosmology.
    Plus all :class:`BAOTheory` attributes (``qpar``, ``qper``, ``qiso``, ``qap``, ...).

    Reference
    ---------
    https://arxiv.org/abs/2106.07641, https://arxiv.org/pdf/2212.04522.pdf
    """

    def __init__(self, z=1., eta=1./3., kp=0.03, n_varied=False, with_now='peakaverage', fiducial='DESI', cosmo=None):
        super().__init__(z=z, eta=eta, fiducial=fiducial, cosmo=cosmo)

    def __post_init__(self, z=1., eta=1./3., kp=0.03, n_varied=False, with_now='peakaverage', fiducial='DESI', cosmo=None):
        from cosmoprimo import PowerSpectrumBAOFilter
        super().__post_init__(z=z, eta=eta, fiducial=fiducial, cosmo=cosmo)
        self._kp = float(kp)
        self._n_varied = bool(n_varied)
        # k grid on which the no-wiggle power spectrum is requested: wide enough to bracket
        # the shifted pivot kp * s for any plausible rd / rd_fid ratio
        self._k_pivot_grid = np.geomspace(self._kp / 3., self._kp * 3., 100)
        requirements = {
            'fourier.pk_now': [{'of': 'delta_cb', 'engine': str(with_now), 'z': self.z, 'k': self._k_pivot_grid}],
            'fourier.sigma8_z': [{'of': 'delta_cb', 'z': self.z}, {'of': 'theta_cb', 'z': self.z}],
            'params.n_s': None,
        }
        if self._n_varied:
            requirements['primordial.pk'] = [{'k': self._k_pivot_grid}]
        self.cosmo.add_requirements(requirements)
        self._with_now = str(with_now)
        # Fiducial quantities
        fo = self._fiducial.get_fourier()
        pk_interp = fo.pk_interpolator(of='delta_cb', **_kw_pk)
        bao_filter = PowerSpectrumBAOFilter(pk_interp, engine=self._with_now, cosmo=self._fiducial, cosmo_fid=self._fiducial)
        pknow_fid = bao_filter.smooth_pk_interpolator().to_1d(z=self.z)(self._k_pivot_grid)
        prim_fid = self._fiducial.get_primordial().pk_interpolator()(self._k_pivot_grid) * self._k_pivot_grid if self._n_varied else None
        self._m_fid = float(self._log_slope(pknow_fid, pk_prim=prim_fid, kp=self._kp))
        self._n_fid = float(self._fiducial.n_s)
        sigma8_fid = fo.sigma8_z(self.z, of='delta_cb')
        fsigma8_fid = fo.sigma8_z(self.z, of='theta_cb')
        Ap_fid = jnp.exp(jnp.interp(np.log(self._kp), np.log(self._k_pivot_grid), np.log(pknow_fid)))
        self._Ap_fid = float(Ap_fid)
        self._f_sqrt_Ap_fid = float(fsigma8_fid / sigma8_fid * Ap_fid ** 0.5)
        self._rd_fid = float(self._fiducial.rs_drag)

    def _log_slope(self, pknow, pk_prim=None, kp=None):
        """Log-slope of *pknow* (divided by the primordial ``pk * k`` when ``n_varied``) at *kp*."""
        log_pknow = jnp.log(pknow)
        if pk_prim is not None:
            log_pknow = log_pknow - jnp.log(pk_prim)
        dk = 1e-2
        logk_pivots = jnp.log(kp) + jnp.array([np.log1p(-dk), np.log1p(dk)])
        log_pknow_pivots = jnp.interp(logk_pivots, np.log(self._k_pivot_grid), log_pknow)
        return (log_pknow_pivots[1] - log_pknow_pivots[0]) / (logk_pivots[1] - logk_pivots[0])

    def __call__(self):
        super().__call__()
        rd = self.cosmo.get_thermodynamics().rs_drag
        s = rd / self._rd_fid
        kp = self._kp * s
        pknow = self.cosmo.get('fourier.pk_now', of='delta_cb', engine=self._with_now, z=self.z, k=self._k_pivot_grid)
        pk_prim = self.cosmo.get('primordial.pk', k=self._k_pivot_grid) * self._k_pivot_grid if self._n_varied else None
        self.m = self._log_slope(pknow, pk_prim=pk_prim, kp=kp)
        self.n = self.cosmo.get('params.n_s')
        self.dm = self.m - self._m_fid
        self.dn = self.n - self._n_fid
        sigma8 = self.cosmo.get('fourier.sigma8_z', of='delta_cb', z=self.z)
        fsigma8 = self.cosmo.get('fourier.sigma8_z', of='theta_cb', z=self.z)
        # Eq. 3.11 of https://arxiv.org/abs/2106.07641
        Ap = jnp.exp(jnp.interp(jnp.log(kp), np.log(self._k_pivot_grid), jnp.log(pknow))) / s ** 3
        self.Ap = Ap
        self.f_sqrt_Ap = fsigma8 / sigma8 * Ap ** 0.5
        self.df = self.f_sqrt_Ap / self._f_sqrt_Ap_fid
        self.dA = self.Ap / self._Ap_fid
        
        return self

    def tree_flatten(self):
        leaves, aux = super().tree_flatten()
        return leaves + [self.m, self.n, self.dm, self.dn, self.df, self.f_sqrt_Ap, self.Ap, self.dA], aux

    @classmethod
    def tree_unflatten(cls, aux, children):
        obj = object.__new__(cls)
        (obj.DH_over_rd, obj.DM_over_rd, obj.DH_over_DM, obj.DV_over_rd, obj.F_AP,
         obj.qpar, obj.qper, obj.qiso, obj.qap,
         obj.m, obj.n, obj.dm, obj.dn, obj.df, obj.f_sqrt_Ap, obj.Ap, obj.dA) = children
        obj.z = aux['z']
        return obj

# %%
class ShapeFitApSpectrum2Template(Spectrum2Template):
    r"""
    ShapeFit power spectrum template.

    Multiplies the fiducial power spectrum by a k-dependent tilt factor controlled by ``dm`` and ``dn``.

    Parameters
    ----------
    k : array, default=None
        Wavenumbers [h/Mpc]. Defaults to np.logspace(-3, 1, 400).
    z : float, default=1.
        Effective redshift.
    fiducial : str, tuple, dict, or cosmoprimo.Cosmology, default='DESI'
        Fiducial cosmology.
    with_now : str or False, default='peakaverage'
        Engine for the no-wiggle power spectrum ('peakaverage', 'wallish2018').
        Set to False to skip (pknow_dd is set equal to pk_dd).
    only_now : bool, default=False
        Replace pk_dd with pknow_dd so wiggles are absent.
    apmode : str, default='qparqper'
        AP parameterization: 'qparqper', 'qisoqap', 'qiso', or 'qap'.
    eta : float, default=1./3.
        Exponent in qiso = qpar**eta * qper**(1 - eta).
    kp : float, default=0.03
        Pivot wavenumber [h/Mpc] for the ShapeFit parameterization.
    a : float, default=0.6
        Steepness parameter in the ShapeFit tilt function.

    Attributes set by ``__call__``
    --------------------------------
    pk_dd, pknow_dd : ndarray, shape (n_k,)
        Full and smooth (no-wiggle) power spectra.
    f, f0, fk : float or ndarray
        Growth rate.
    qpar, qper : float
        AP distortion ratios, derived from the sampled apmode parameters.
    sigma8, fsigma8, sigma8_fid : float
        sigma8 stays at its fiducial value (no amplitude-rescaling parameter); fsigma8
        tracks the df-scaled growth rate.
    """

    @classmethod
    def install(cls, installer):
        installer.pip('git+https://github.com/cosmodesi/cosmoprimo')

    @classmethod
    def propose_params(cls, apmode='qparqper'):
        """Return a proposed :class:`~desilike.parameter.VariableCollection` for this template.

        Parameters
        ----------
        apmode : str, default='qparqper'
            AP parameterization: one of ``'qparqper'``, ``'qisoqap'``, ``'qiso'``, ``'qap'``.

        Returns
        -------
        VariableCollection
        """
        return propose_params_multitracer(
            _ap_auto_params(apmode) + [
                Parameter('df', value=1., prior=dict(limits=[0., 20.]),
                          ref=dict(dist='norm', loc=1., scale=0.05), fd_eps=0.02, latex=r'\delta f'),
                Parameter('dm', value=0., prior=dict(limits=[-0.5, 0.5]),
                          ref=dict(dist='norm', loc=0., scale=0.05), fd_eps=0.01, latex=r'\delta m'),
                Parameter('dn', value=0., fixed=True, prior=dict(limits=[-0.5, 0.5]),
                          ref=dict(dist='norm', loc=0., scale=0.05), fd_eps=0.01, latex=r'\delta n'),
                Parameter('dA', value=1., fixed=True, prior=dict(limits=[0., 20.]),
                          ref=dict(dist='norm', loc=1., scale=0.05), fd_eps=0.02, latex=r'\delta A_{p}'),
            ], tracers=None)

    def __init__(self, k=None, z=1., fiducial='DESI', with_now='peakaverage',
                 only_now=False, apmode='qparqper', eta=1. / 3., kp=0.03, a=0.6, params=None):
        vc = type(self).propose_params(apmode=str(apmode))
        if params is not None:
            vc = vc + VariableCollection(params)
        assign_params(self, vc, None)
        # See BAOSpectrum2Template.__init__: _qpar_qper() reads from self.params rather
        # than self.qpar/self.qper, since __call__ reassigns those to the derived output.
        self.params = vc

    def __post_init__(self, k=None, z=1., fiducial='DESI', with_now='peakaverage',
                      only_now=False, apmode='qparqper', eta=1. / 3., kp=0.03, a=0.6, params=None):
        from cosmoprimo import PowerSpectrumBAOFilter

        self._apmode = str(apmode)
        self._eta = float(eta)
        self._only_now = bool(only_now)
        self._kp = float(kp)
        self._a = float(a)

        if k is None:
            k = np.logspace(-3., 1., 400)
        self.k = np.asarray(k, dtype='f8')
        self.z = float(z)

        self._fiducial = _get_fiducial(fiducial)
        self._rs_drag_fid = float(self._fiducial.rs_drag)

        fo = self._fiducial.get_fourier()
        sigma8 = fo.sigma8_z(z, of='delta_cb')
        fsigma8 = fo.sigma8_z(z, of='theta_cb')
        self._sigma8_fid = float(sigma8)
        self._fsigma8_fid = float(fsigma8)
        self._f_fid = float(fsigma8 / sigma8)

        pk_interp = fo.pk_interpolator(of='delta_cb', **_kw_pk).to_1d(z=z)
        ptt_interp = fo.pk_interpolator(of='theta_cb', **_kw_pk).to_1d(z=z)

        k0 = 1e-3
        self._f0_fid = float(np.sqrt(ptt_interp(k0) / pk_interp(k0)))
        self._fk_fid = np.sqrt(ptt_interp(self.k) / pk_interp(self.k))
        self._pk_dd_fid = pk_interp(self.k)

        if with_now:
            bao_filter = PowerSpectrumBAOFilter(pk_interp, engine=with_now, cosmo=self._fiducial, cosmo_fid=self._fiducial)
            self._pknow_dd_fid = bao_filter.smooth_pk_interpolator()(self.k)
        else:
            self._pknow_dd_fid = self._pk_dd_fid
        self.sigma8_fid = jnp.asarray(self._sigma8_fid)

    def _qpar_qper(self):
        if self._apmode == 'qparqper':
            return self.params['qpar'].value, self.params['qper'].value
        if self._apmode == 'qiso':
            q = self.params['qiso'].value
            return q, q
        if self._apmode == 'qap':
            qap = self.params['qap'].value
            return qap ** (1. - self._eta), qap ** (-self._eta)
        qiso, qap = self.params['qiso'].value, self.params['qap'].value
        return qiso * qap ** (1. - self._eta), qiso * qap ** (-self._eta)

    def ap_k_mu(self, k, mu):
        """Apply AP distortion to a (k, mu) grid; returns (jac, kap, muap)."""
        qpar, qper = self._qpar_qper()
        return _ap_k_mu(k, mu, qpar, qper)

    def __call__(self):
        dm = self.dm.value
        dn = self.dn.value
        df = self.df.value
        dA = self.dA.value
        factor = dA * jnp.exp(dm / self._a * jnp.tanh(self._a * jnp.log(self.k / self._kp))
                         + dn * jnp.log(self.k / self._kp))
        self.pk_dd = self._pk_dd_fid * factor
        self.pknow_dd = self._pknow_dd_fid * factor
        if self._only_now:
            self.pk_dd = self.pknow_dd
        self.f = self._f_fid * df
        self.f0 = self._f0_fid * df
        self.fk = self._fk_fid * df
        qpar, qper = self._qpar_qper()
        self.qpar = qpar
        self.qper = qper
        tanh_arg = self._a * jnp.log(self._rs_drag_fid / 8.)
        sigma8_sq_ratio = dA * jnp.exp((dm + dn) / self._a * jnp.tanh(tanh_arg))
        self.sigma8 = self._sigma8_fid * jnp.sqrt(sigma8_sq_ratio)
        self.fsigma8 = self._fsigma8_fid * df
        self.sigma8_fid = jnp.asarray(self._sigma8_fid)
        return self.pk_dd

    def tree_flatten(self):
        return ([self.pk_dd, self.pknow_dd, self.f, self.f0, self.fk, self.qpar, self.qper,
                 self.sigma8, self.fsigma8, self.sigma8_fid, self.dA], {'k': self.k})

    @classmethod
    def tree_unflatten(cls, aux, children):
        obj = object.__new__(cls)
        (obj.pk_dd, obj.pknow_dd, obj.f, obj.f0, obj.fk, obj.qpar, obj.qper,
         obj.sigma8, obj.fsigma8, obj.sigma8_fid, obj.dA) = children
        obj.k = aux['k']
        return obj

# %%
template = ShapeFitApSpectrum2Template(z=z, fiducial='DESI')
theory = KaiserTracerSpectrum2Poles(template=template)

data_sel = data.get(ells=[0, 2]).select(k=(0.02, 0.2))  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
covariance = lsstypes.cov(mocks).at.observable.match(data_sel)
observable = Spectrum2PolesObservable(data=data_sel, covariance=covariance, theory=theory)

# NOTE: parameter customization must happen AFTER building the observable above, not before:
# Spectrum2PolesObservable.__init__ calls theory.update(k=..., ells=...) internally to align the
# theory's grid with the data, which (being a full re-__init__) would otherwise silently
# discard any customization made on theory's params beforehand.
params = get_params(observable)
params['b1'].update(value=2.)  # start from the truth
# Narrow reference distributions (used to draw starting points for profilers / samplers)
params['dm'].update(ref={'limits': [-0.001, 0.001]})
params['df'].update(ref={'limits': [0.99, 1.01]})
params['dA'].update(ref={'limits': [0.99, 1.01]}, fixed = False)
for name in ['qpar', 'qper']: params[name].update(ref={'limits': [0.998, 1.002]})

likelihood = ObservablesGaussianLikelihood(observables=[observable])

# NOTE: if we wanted to fit xi instead:
# theory = KaiserTracerCorrelation2Poles(template=template)
# observable = Correlation2PolesObservable(data=data_sel, covariance=covariance,
#                                          theory=theory)  # with data_sel = data.get(ells=[0, 2]).select(s=(40., 160.))
# The rest would be the same

setup_logging()
pipe = compile(likelihood)
print('logL at default parameters =', pipe())
# Out:
# logL at default parameters = -17.968458230565233

# %%
from desilike import TaylorEmulator

# Taylor-expand the theory as set up by the observable (k and ells aligned with the data),
# around the current parameter values: order 2 in all parameters, except sn0
# (the theory is linear in sn0, so order 1 is enough)
theory_graph = compile(theory)
order = {name: 2 for name in get_params(theory).select(varied=True, derived=False).names()}
order['sn0'] = 1
emulator = TaylorEmulator(theory_graph, order=order)
emulator.fit()

# NOTE: the pre-refactor Emulator.check()/.plot() convenience methods no longer exist;
# compare the emulator directly against the original model instead
point = dict(qpar=1.002, qper=0.998, dm=0.005, df=1.005, b1=2.1, sn0=0.1)
y_true = np.asarray(theory_graph(**point))
y_emu, _ = emulator.predict(point)
print('Max relative emulation error:', np.max(np.abs(np.asarray(y_emu) / y_true - 1.)))

import os
base_dir = '_tests'
os.makedirs(base_dir, exist_ok=True)
kaiser_emulator_fn = os.path.join(base_dir, 'Ap_kaiser_emulator.h5')
emulator.write(kaiser_emulator_fn)
# Out:
# [000005.72]  07-22 01:20  TaylorEmulator               INFO     Varied parameters: ['df', 'dm', 'dA', 'qpar', 'qper', 'b1', 'sn0']
# Max relative emulation error: 3.8183863705243404e-05

# %%
from desilike import Sampler, Posterior
from desilike.samplers import Zeus, PocoMC, Nautilus

# Swap the theory for its emulator: update() re-runs the observable's __init__ in-place with
# the new theory (the likelihood holds the same observable instance, so it picks up the swap
# when we recompile below). The emulated calculator is a drop-in replacement for the original.
emulated = TaylorEmulator.read(kaiser_emulator_fn).to_calculator()
#observable.update(theory=emulated)

# Sample the posterior = likelihood + priors: wrap the likelihood in Posterior.
# (Sampling the bare likelihood would let walkers wander far outside the priors,
# where the Taylor emulator extrapolates arbitrarily badly.)
pipe = compile(Posterior(likelihood))
! rm -rfv _tests/chain_fs_shapefit_Ap/
sampler = Sampler(pipe, kernel=Zeus(), rng=42, output_dir='_tests/chain_fs_shapefit_Ap')
# We run samples until convergence, considered reached when Gelman-Rubin stabilizes below 1.05
samples = sampler.run(min_steps=2000, gelman_rubin=1.01)
#samples = sampler.run()
# Out:
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20260321-1.0.0/conda/lib/python3.12/pty.py:95: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# /bin/bash: module: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `module'
# /bin/bash: ml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `ml'
# removed '_tests/chain_fs_shapefit_Ap/samples_1.h5'
# removed '_tests/chain_fs_shapefit_Ap/checks.json'
# removed '_tests/chain_fs_shapefit_Ap/rng_1.json'
# removed directory '_tests/chain_fs_shapefit_Ap/'
# [000038.99]  07-22 01:20  EnsembleSampler              INFO     Varied parameters: ['df', 'dm', 'dA', 'qpar', 'qper', 'b1', 'sn0']
# ...

# %%
chain = samples.remove_burnin(0.5)[::10]
print(chain.to_stats(tablefmt='pretty'))
# Out:
# +------+---------+---------+---------+--------+-----------------+-----------------+
# |      | argmax  |  mean   | median  |  std   | quantile:1sigma | interval:1sigma |
# +------+---------+---------+---------+--------+-----------------+-----------------+
# |  df  |  0.74   |  1.08   |  1.06   |  0.25  |   +0.29/-0.28   |   +0.15/-0.37   |
# |  dm  | -0.0005 | -0.0015 | -0.0014 | 0.0061 | +0.0061/-0.0062 | +0.0061/-0.0062 |
# |  dA  |  1.80   |  0.99   |  0.88   |  0.45  |   +0.57/-0.47   |   +0.19/-0.59   |
# | qpar | 0.9999  | 1.0002  | 1.0002  | 0.0027 | +0.0027/-0.0027 | +0.0026/-0.0028 |
# | qper | 0.9946  | 0.9942  | 0.9941  | 0.0051 | +0.0053/-0.0052 | +0.0048/-0.0055 |
# |  b1  |  1.49   |  2.16   |  2.12   |  0.49  |   +0.60/-0.57   |   +0.28/-0.76   |
# | sn0  | 0.0017  | 0.0026  | 0.0026  | 0.0029 | +0.0029/-0.0029 | +0.0029/-0.0029 |
# +------+---------+---------+---------+--------+-----------------+-----------------+

# %%
from desilike.samples import plotting
from desilike.samples import MCSamples
chain = MCSamples.read('_tests/chain_fs_shapefit_Ap/samples_1.h5').remove_burnin(0.3)
chain_no_Ap = MCSamples.read('_tests/chain_fs_shapefit/samples_1.h5').remove_burnin(0.3)
chain_no_Ap['dA'] = np.random.uniform(size = chain_no_Ap['dm'].value.shape) * 2.

plotting.plot_triangle([chain, chain_no_Ap], markers={'qpar': 1., 'qper': 1., 'df': 1., 'dA':1., 'dm': 0., 'b1': b, 'sn0': 0.})
# Out:
# Removed no burn in
# Removed no burn in
# [000514.40]  07-22 01:28  root                         WARNING  auto bandwidth for df very small or failed (h=0.0006140406700126623,N_eff=499800.0). Using fallback (h=0.014590472556874899)
# [000514.49]  07-22 01:28  root                         WARNING  auto bandwidth for dm very small or failed (h=0.0006055485577032373,N_eff=499800.0). Using fallback (h=0.008967804493822855)
# [000514.57]  07-22 01:28  root                         WARNING  auto bandwidth for dA very small or failed (h=0.000570613678076216,N_eff=499800.0). Using fallback (h=0.011824121005038473)
# [000514.66]  07-22 01:28  root                         WARNING  auto bandwidth for qpar very small or failed (h=0.0006805825889034601,N_eff=499800.0). Using fallback (h=0.009966457063265868)
# [000514.81]  07-22 01:28  root                         WARNING  auto bandwidth for b1 very small or failed (h=0.0005894433752844429,N_eff=499800.0). Using fallback (h=0.01458458394454402)
# ...

# %%
from desilike.base import Calculator
import lsstypes as types
from desilike.observables.galaxy_clustering.stats import _format_clustering_data_window_covariance, _parse_templates
class Spectrum3PolesObservable(Calculator):
    r"""
    Bispectrum multipoles observable.

    Computes ``flattheory = window_matrix @ theory.poles.ravel()`` and
    stores ``flatdata`` for comparison by a likelihood.

    Parameters
    ----------
    data : array, lsstypes.Mesh3SpectrumPoles, or None
        Flat data vector or lsstypes observable. If None, set to zeros
        (requires ``k``).
    theory : Calculator
        Theory calculator that exposes a ``spectrum`` attribute after calling.
    k : list of arrays, default=None
        Wavenumbers per multipole (required when ``data`` is a plain array and
        ``window`` is None).
    ells : tuple, default=None
        Multipole orders. Extracted from ``data`` when it is a lsstypes object;
        defaults to ``((0, 0, 0), (2, 0, 2))`` otherwise.
    window : 2-D array, lsstypes.WindowMatrix, or None, default=None
        Window matrix. If None a trivial identity selection is used.
    kin : array, default=None
        Theory wavenumbers (required when ``window`` is a plain 2-D array).
    ellsin : tuple, default=None
        Theory multipoles (required when ``window`` is a plain 2-D array).
    covariance : 2-D array, lsstypes.CovarianceMatrix, or None, default=None
        Covariance matrix stored for use by :class:`ObservablesGaussianLikelihood`.
    templates : list of (Parameter or dict, array) pairs, or None, default=None
        Extra linear templates added to the theory prediction.  Each entry is
        ``(param, array)`` where *param* is a :class:`Parameter` instance (or a dict
        of keyword arguments for ``Parameter(**param)``) and *array* has shape
        ``(n_data,) + param.shape``.  The contribution ``array.reshape(n_data, -1) @
        ravel(param.value)`` is added to ``flattheory`` after window convolution.
    name : str, default='spectrum3poles'
        Observable name.

    Attributes set by ``__call__``
    --------------------------------
    flattheory : ndarray, shape (n_data,)
        Window-convolved theory prediction plus any template contributions.
    """

    def __init__(self, data, theory, k=None, ells=None,
                 window=None, kin=None, ellsin=None,
                 covariance=None, templates=None, name='spectrum3poles'):
        self.name = str(name)
        if not isinstance(data, types.ObservableLike) and ells is not None:
            if hasattr(ells[0], '__iter__'):
                ells = [tuple(ell) for ell in ells]
            else:
                ells = [int(ell) for ell in ells]
        self.data, self.window, self.covariance = _format_clustering_data_window_covariance(
            data=data, window=window, covariance=covariance,
            coords=k, ells=ells, coordin=kin, ellsin=ellsin, coord_name='k')
        self.flatdata = self.data.value()
        self._window_matrix = self.window.value()
        self.theory = theory
        self.theory.update(k=next(iter(self.window.theory)).coords('k'),
                           ells=self.window.theory.ells)
        self.templates = _parse_templates(templates, n_data=self.flatdata.size)

    def __call__(self):
        print(self._window_matrix.shape, self.theory.poles.shape)
        self.flattheory = jnp.dot(self._window_matrix, jnp.ravel(self.theory.poles))
        self.flattheory = _apply_templates(self.flattheory, self.templates)
        return self.flattheory

    @plotting.plotter(interactive={'kw_theory': {'color': 'black', 'label': 'reference'}})
    def plot(self, kw_theory=None, fig=None):
        """
        Plot data and theory bispectrum multipoles.

        Parameters
        ----------
        kw_theory : dict or list of dict, default=None
            Line style overrides for the theory curve, one dict per multipole.
        fig : matplotlib.figure.Figure, default=None
            Existing figure with at least ``1 + len(ells)`` axes.
        fn : str or Path, default=None
            Path where to save the figure.
        kw_save : dict, default=None
            Extra arguments for :meth:`matplotlib.figure.Figure.savefig`.
        show : bool, default=False
            Call :func:`matplotlib.pyplot.show` after returning.

        Returns
        -------
        fig : matplotlib.figure.Figure
        """
        if kw_theory is None:
            kw_theory = {}
        if isinstance(kw_theory, dict):
            kw_theory = [kw_theory]
        labels = self.data.labels()
        if len(kw_theory) != len(labels):
            kw_theory = [{key: value for key, value in kw_theory[0].items()
                          if key != 'label' or ill == 0}
                         for ill in range(len(labels))]
        kw_theory = [{'color': f'C{ill:d}', **kw} for ill, kw in enumerate(kw_theory)]

        if fig is None:
            height_ratios = [max(len(labels), 3)] + [1] * len(labels)
            figsize = (6, 1.5 * sum(height_ratios))
            fig, lax = plt.subplots(len(height_ratios), sharex=True, sharey=False,
                                    gridspec_kw={'height_ratios': height_ratios},
                                    figsize=figsize, squeeze=True)
            fig.subplots_adjust(hspace=0.1)
            show_legend = True
        else:
            lax = fig.axes
            show_legend = False

        wtheory = self.data.clone(value=np.asarray(self.flattheory))
        xlabel = ylabel = None
        xx = []
        for ill, label in enumerate(labels):
            ell = label['ells']
            data_pole = self.data.get(**label)
            wtheory_pole = wtheory.get(**label)
            k_array = data_pole.coords('k')
            if 'scoccimarro' in data_pole.basis:
                x = np.arange(data_pole.size)
                scale = k_array.prod(axis=-1)
                xlabel = r'triangle index'
                ylabel = r'$k_1 k_2 k_3 B_{\ell}(k_1, k_2, k_3)$ [$(\mathrm{Mpc}/h)^3$]'
            else:
                scale = k_array.prod(axis=-1)
                if np.allclose(k_array[..., 1], k_array[..., 0]):
                    x = k_array[..., 0]
                    xlabel = r'$k$ [$h/\mathrm{Mpc}$]'
                else:
                    x = np.arange(data_pole.size)
                    xlabel = r'triangle index'
                ylabel = r'$k^2 B_{\ell}(k, k)$ [$(\mathrm{Mpc}/h)^4$]'
            xx.append(x)
            std = self.covariance.at.observable.get(**label).std()
            lax[0].errorbar(x, scale * data_pole.value(), yerr=scale * std,
                            color=kw_theory[ill]['color'], linestyle='none', marker='o',
                            label=rf'$\ell = {ell}$')
            lax[0].plot(x, scale * wtheory_pole.value(), **kw_theory[ill])
        for ill, label in enumerate(labels):
            ell = label['ells']
            data_pole = self.data.get(**label)
            wtheory_pole = wtheory.get(**label)
            std = self.covariance.at.observable.get(**label).std()
            lax[ill + 1].plot(xx[ill], (data_pole.value() - wtheory_pole.value()) / std, **kw_theory[ill])
            lax[ill + 1].set_ylim(-4, 4)
            for offset in [-2., 2.]:
                lax[ill + 1].axhline(offset, color='k', linestyle='--')
            lax[ill + 1].set_ylabel(rf'$\Delta B_{{{ell}}} / \sigma_{{B_{{{ell}}}}}$')

        for ax in lax:
            ax.grid(True)
        if show_legend:
            lax[0].legend()
        if ylabel is not None:
            lax[0].set_ylabel(ylabel)
        if xlabel is not None:
            lax[-1].set_xlabel(xlabel)
        return fig

    def tree_flatten(self):
        return [self.flattheory, self.flatdata], None

    @classmethod
    def tree_unflatten(cls, aux, children):
        obj = object.__new__(cls)
        obj.flattheory, obj.flatdata = children
        return obj

# %%
template_b = ShapeFitApSpectrum2Template(z=z, fiducial='DESI')
theory_b = FOLPSTracerSpectrum3Poles(template=template_b)

data_sel = data.get(ells=[0, 2]).select(k=(0.02, 0.2))  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
covariance = lsstypes.cov(mocks).at.observable.match(data_sel)
observable = Spectrum2PolesObservable(data=data_sel, covariance=covariance, theory=theory)


covariance_b = lsstypes.cov(mocks_b).at.observable.match(data_b)
observable_b = Spectrum3PolesObservable(data=data_b, covariance=covariance_b, theory=theory_b)



# NOTE: parameter customization must happen AFTER building the observable above, not before:
# Spectrum2PolesObservable.__init__ calls theory.update(k=..., ells=...) internally to align the
# theory's grid with the data, which (being a full re-__init__) would otherwise silently
# discard any customization made on theory's params beforehand.
params = get_params(observable)
params['b1'].update(value=2.)  # start from the truth
# Narrow reference distributions (used to draw starting points for profilers / samplers)
params['dm'].update(ref={'limits': [-0.001, 0.001]})
params['df'].update(ref={'limits': [0.99, 1.01]})
for name in ['qpar', 'qper']: params[name].update(ref={'limits': [0.998, 1.002]})


params = get_params(observable_b)
params['b1'].update(value=2.)  # start from the truth
# Narrow reference distributions (used to draw starting points for profilers / samplers)
params['dm'].update(ref={'limits': [-0.001, 0.001]})
params['df'].update(ref={'limits': [0.99, 1.01]})
for name in ['qpar', 'qper']: params[name].update(ref={'limits': [0.998, 1.002]})

likelihood = ObservablesGaussianLikelihood(observables=[observable, observable_b], covariance = cov_joint)

# NOTE: if we wanted to fit xi instead:
# theory = KaiserTracerCorrelation2Poles(template=template)
# observable = Correlation2PolesObservable(data=data_sel, covariance=covariance,
#                                          theory=theory)  # with data_sel = data.get(ells=[0, 2]).select(s=(40., 160.))
# The rest would be the same

setup_logging()
pipe = compile(likelihood)
print('logL at default parameters =', pipe())
observable_b.plot()
# Out:
# Calculating matrices (no save path specified)
# (38, 38) (2, 1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 42
#      35 # NOTE: if we wanted to fit xi instead:
#      36 # theory = KaiserTracerCorrelation2Poles(template=template)
#      37 # observable = Correlation2PolesObservable(data=data_sel, covariance=covariance,
#      38 #                                          theory=theory)  # with data_sel = data.get(ells=[0, 2]).select(s=(40., 160.))
#      39 # The rest would be the same
#      41 setup_logging()
# ---> 42 pipe = compile(likelihood)
#      43 print('logL at default parameters =', pipe())
#      44 observable_b.plot()
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20260321-1.0.0/code/desilike/refactor-jax/lib/python3.12/site-packages/desilike/base.py:1905, in compile(root, output, input)
# ...
